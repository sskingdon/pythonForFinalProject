# %%
#encoding=utf-8
import jieba

# %%
content = open('[遊記] 北海道 洞爺湖 昭和新山 有珠山纜車.txt',encoding="UTF-8").read()

# %%
print(content)
# Out:
# ﻿昭和新山有珠山纜車
# 地址：北海道有珠郡壮瞥町字昭和新山184-5
# 電話：0142-75-2401
# 官網：http://wakasaresort.com/usuzan/
# 纜車費用：大人1,500円 小學生 750円
#
#
# 圖文網誌
# http://vivayeu.pixnet.net/blog/post/337033745
#
# 結束完大沼公園親子腳踏車環湖之旅後
# 去洞爺湖乃之風check in 之前
# 安排一個離洞爺湖乃之風車程約10分鐘的景點
# 到昭和新山搭有珠山纜車看風景去~
#
# 更多北海道親子行行程與花費 https://goo.gl/kaV5Go
#
# 來昭和新山 主要是打算搭有珠山纜車 一覽洞爺湖以及昭和新山的美景
# 進入昭和新山都要收取停車費500日圓
# 停車的地方 離有珠山纜車 走路約要5分鐘
# 走過去的路上 就有不少人在這昭和新山 支笏洞爺國立公園的牌子前拍個照
# 我也不免俗 跟女兒來張遊客到此一遊照吧~~
#
# 而有珠山纜車旁邊就有 昭和新山熊牧場
# 不少團客也會安排到這熊牧場來看熊
# 不過這趟旅行 對於去熊牧場看熊沒興趣XD 就沒入內了
#
# 搭乘有珠纜車入口處外 就有可愛的看板
# 哈 強迫女兒跟看板一起照
#
# 要搭纜車必須走上二樓 而一樓主要是販賣一些紀念品
# 有珠山纜車的費用 其實也不便宜
# 要1500日圓(ORIX有提供折價券 一人可折150日圓 變1350日圓)
# 而且還不能刷卡XD
# 很快的 買好票 纜車就來了 纜車其實很大一台
#
# 個人覺得纜車還蠻穩的
# 而窗外的風景美不勝收!!
# 搭乘空中纜車約6分鐘就可到達有珠山山頂
# 一到山頂可一覽無遺洞爺湖及昭和新山的美景
#
# 只能說 老天爺很幫忙 給我們一個超好的天氣
# 好天氣加美景 讓人心情無敵愉悅
#
# 走另一頭到半路發現 需要爬上一長段的階梯
# 因為是推著嬰兒車 有長階梯真的是要命  為了怕夫妻失和 我就不嘗試了
# 所以只好下山拉
# 等纜車下山處旁有紀念品區 還有視聽室
# 建議安排行程時 要注意有珠山纜車下山纜車最後的時間喔
# 免得錯過最後一班纜車 就囧了
# 纜車運行時間表http://wakasaresort.com/usuzan/access/index.html
#
# ...

# %%
 jieba.load_userdict("Hokkaido.txt")
# Out:
# Building prefix dict from the default dictionary ...
# Dumping model to file cache C:\Users\HOME\AppData\Local\Temp\jieba.cache
# Loading model cost 0.993 seconds.
# Prefix dict has been built succesfully.

# %%
words=jieba.cut(content)

# %%
for word in words:
    print(word)
# Out:
# ﻿
# 昭和新山
# 有
# 珠山
# 纜車
#
#
# 地址
# ：
# 北海道
# 有珠
# 郡
# 壮瞥
# 町
# 字
# 昭和新山
# 184
# -
# 5
#
#
# 電話
# ：
# 0142
# -
# 75
# -
# 2401
#
#
# 官網
# ：
# http
# :
# /
# /
# wakasaresort
# .
# com
# /
# usuzan
# /
#
#
# 纜車
# 費用
# ：
# 大人
# 1
# ,
# 500
# 円
#
# 小學生
#
# 750
# 円
#
#
#
#
#
#
# 圖文
# 網誌
#
#
# http
# :
# /
# /
# vivayeu
# .
# pixnet
# .
# net
# /
# blog
# /
# post
# /
# 337033745
#
#
#
#
# 結束
# 完大
# 沼公園
# 親子
# 腳踏車
# 環湖
# 之
# 旅
# 後
#
#
# 去
# 洞爺湖
# 乃之風
# check
#
# in
#
# 之前
#
#
# 安排
# 一個
# 離
# 洞爺湖
# 乃之風
# 車程
# 約
# 10
# 分鐘
# 的
# 景點
#
#
# 到
# 昭和新山
# 搭有
# 珠山
# 纜車
# 看風景
# 去
# ~
#
#
#
#
# 更
# 多
# 北海道
# 親子行
# 行程
# 與
# 花費
#
# https
# :
# /
# /
# goo
# .
# gl
# /
# kaV5Go
#
#
#
#
# 來
# 昭和新山
#
# 主要
# 是
# 打算
# 搭有
# 珠山
# 纜車
#
# 一覽
# 洞爺湖
# 以及
# 昭和新山
# 的
# 美景
#
#
# 進入
# 昭和新山
# 都
# 要
# 收取
# 停車費
# 500
# 日圓
#
#
# 停車
# 的
# 地方
#
# 離有
# 珠山
# 纜車
#
# 走路
# 約
# 要
# 5
# 分鐘
#
#
# 走過
# 去
# 的
# 路上
#
# 就
# 有
# 不少
# 人
# 在
# 這
# 昭和新山
#
# 支笏
# 洞爺
# 國立
# 公園
# 的
# 牌子
# 前
# 拍個
# 照
#
#
# 我
# 也
# 不
# 免俗
#
# 跟
# 女兒
# 來
# 張遊客
# ...

# %%
Hokkaidodict = open('Hokkaido.txt',encoding="UTF-8").read()

# %%
tt=[]
with open('Hokkaido.txt',encoding="UTF-8") as f:
    for i in f:
      tt.append(i.strip())

# %%
print(tt)
# Out:
# ['-------55城66--------', '五稜郭', '龜田役所土壘', '志苔館', '染退砦', 'シベチャリチャシ', '四稜郭', '根室半島砦跡群', '根室半島チャシ跡群', '辯天台場', '松前城', 'Moshiriya砦', 'モシリヤチャシ', '--------55寺66-------', '國泰寺', '-------55神社66------', '北海道神宮', '函館八幡宮', '千歳神社', '樽前山神社', '金比羅神社', '金刀比羅神社', '上川神社', '帶廣神社', '蘆別神社', '-----55地理名詞66-----', '渡島小島', '渡島大島', '奧尻島', '天賣島', '燒尻島', '利尻島', '禮文島', '阿寒湖', '摩周湖', '屈斜路湖', '支笏湖', '支笏', '洞爺湖', '佐呂間湖', '網走湖', '能取湖', '風蓮湖', '札幌', '函館', '旭川', '網走', '根室', '庫頁島', '宗谷海峽', '鄂霍次克海', '富良野', '---------', '函館空港', '金森倉庫群', '大沼國立公園', '昭和新山', '熊牧場', '洞爺湖', '登別地獄谷', '狸小路', '小樽', '北一哨子館', '小樽音樂盒館博物館', '小樽水族館', '塘鵝逛水族館', '北海道神宮', '支笏湖', '千歲空港', '旭山動物園', '層雲峽', '石狩川', '鄂霍茨克塔', '網走監獄博物館', '阿寒鶴居村', '幣舞橋', '帶廣空港', '五稜郭公園', '十勝川', '標津鮭魚科學館', '知床國立公園', '網走刑務所博物館', '北見薄荷紀念館', '札幌電視塔', '流冰映像館', '昆布館', '函館山', '洞爺湖畔雕刻公園', '洞爺湖展望台', '洞爺湖展望台', '朝日啤酒工廠', '伊達時代村', '然別湖', '冰幻之村', '池田葡萄牙酒廠', '阿寒湖', '路經時計台', '舊道廳', '明治館', '橫丁市場', '白老愛奴文化村', '余市威士忌蒸餾所', '余市威士忌小鎮', '石屋', '巧克力工廠', '羊之丘展望台', '芝櫻庭園', '尻別河畔公園', '五稜郭公園', '新青森駅', '青函隧道
# ...

# %%
print(words)
# Out:
# <generator object Tokenizer.cut at 0x0000029730FC8FC0>

# %%
words
# Out:
# <generator object Tokenizer.cut at 0x0000029730FC8FC0>

# %%
A=set()
words=jieba.cut(content)
for word in words:
    for ltt in tt:
        if word == ltt:
            print(ltt)
            A.add(ltt)
# Out:
# 昭和新山
# 昭和新山
# 洞爺湖
# 洞爺湖
# 洞爺湖
# 洞爺湖
# 昭和新山
# 昭和新山
# 洞爺湖
# 洞爺湖
# 昭和新山
# 昭和新山
# 昭和新山
# 支笏
# 昭和新山
# 熊牧場
# 熊牧場
# 熊牧場
# 洞爺湖
# 洞爺湖
# 昭和新山
# 洞爺湖
# 洞爺湖
# 昭和新山
# 洞爺湖
# 洞爺湖
# 昭和新山

# %%
A
# Out:
# {'支笏', '昭和新山', '洞爺湖', '熊牧場'}

# %%
#!/usr/bin/python 
import mysql.connector as mariadb 
mariadb_connection = mariadb.connect(user='root', password='54sanchez', database='finalproject') 
cursor = mariadb_connection.cursor()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-3c4c155b0361> in <module>()
#       1 #!/usr/bin/python
# ----> 2 import mysql.connector as mariadb
#       3 mariadb_connection = mariadb.connect(user='root', password='54sanchez', database='finalproject')
#       4 cursor = mariadb_connection.cursor()
#
# ImportError: No module named 'mysql'

# %%
import sys
print(sys.version)
# Out:
# 3.5.2 |Anaconda 4.2.0 (64-bit)| (default, Jul  5 2016, 11:41:13) [MSC v.1900 64 bit (AMD64)]

# %%
import pymysql
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-8-a4103d9b2333> in <module>()
# ----> 1 import pymysql
#
# ImportError: No module named 'pymysql'
