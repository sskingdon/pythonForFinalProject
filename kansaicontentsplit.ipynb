# %%
#encoding=utf-8
import jieba
jieba.load_userdict("./view/Kansai.txt")
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\Student\AppData\Local\Temp\jieba.cache
# Loading model cost 0.702 seconds.
# Prefix dict has been built succesfully.

# %%
import pandas as pd
df = pd.read_csv('2234.csv')

# %%
tt=[]
with open('./view/Kansai.txt',encoding="UTF-8") as f:
    for i in f:
      tt.append(i.strip())

# %%
A=set()
for partcontent in df['content']:
    words=jieba.cut(partcontent)
    for word in words:
        for ltt in tt:
            if word == ltt:
                A.add(ltt)
    if len(A)>1:
        print(A)
    A=set()
# Out:
# {'天滿宮', '北野天滿宮'}
# {'京都車站', '錦市場', '金閣寺', '比叡山', '貴船神社', '琵琶湖', '清水寺', '祇園', '天滿宮', '三千院', '鞍馬寺', '銀閣寺', '延曆寺'}
# {'御堂筋', '通天閣'}
# {'二條城', '知恩院', '京都車站', '河原町', '清水寺'}
# {'醍醐寺', '三寶院'}
# {'鶴見綠地', '長谷寺'}
# {'姬路城', '東大寺', '八坂神社', '奈良公園', '好古園', '知恩院', '錦市場', '本能寺', '神戶港', '清水寺', '心齋橋', '花見小路', '河原町'}
# {'姬路城', '生田神社'}
# {'心齋橋', '嵐山', '環球影城', 'LUCUA', '道頓堀'}
# {'三千院', '嵐山', '渡月橋', '伏見稻荷神社'}
# {'姬路城', '法善寺橫丁', '京都車站', '關西空港', '清水寺'}
# {'臨空城', '八坂神社', '關西空港', '道頓堀', '天橋立', '智恩寺', '天保山', '祇園', '天王寺動物園', '花見小路', '建仁寺', '通天閣', '梅田空中庭園'}
# {'心齋橋', '神戶塔', '鐵人28號'}
# {'八坂神社', '金閣寺', '中之島公園', '大阪城公園', '清水寺', '心齋橋', '環球影城'}
# {'心齋橋', '通天閣', '日本橋'}
# {'全興寺', '海遊館'}
# {'嵐山', '渡月橋', '天龍寺'}
# {'京都車站', '天橋立'}
# {'姬路城', '好古園', '北野異人館', '神戶港', '鐵人28號'}
# {'花見小路', '建仁寺', '祇園'}
# {'寶嚴院', '常寂光寺', '嵐山', '天龍寺', '二尊院'}
# {'道頓堀', '御堂筋', '日本橋', '天保山', '心齋橋', '鶴見綠地', '通天閣'}
# {'北野天滿宮', '金閣寺', '天龍寺', '清水寺', '下鴨神社'}
# {'二條城', '京都御所', '伏見城', '二条城'}
# {'禪林寺', '南禪寺'}
# ...
